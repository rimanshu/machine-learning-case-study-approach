# %%
import graphlab

# %%
# Read csv file
sf = graphlab.SFrame('FL_insurance_sample.csv')
# Out:
# Finished parsing file G:\Githubs repo\machine-learning-assgn\FL_insurance_sample.csv
# Parsing completed. Parsed 100 lines in 0.072212 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[long,str,str,float,float,float,float,float,float,long,float,long,long,float,float,str,str,long]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file G:\Githubs repo\machine-learning-assgn\FL_insurance_sample.csv
# Parsing completed. Parsed 36634 lines in 0.077208 secs.

# %%
sf.head()
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
#
# Rows: 10
#
# Data:
# +----------+-----------+-------------+---------------+---------------+---------------+
# | policyID | statecode |    county   | eq_site_limit | hu_site_limit | fl_site_limit |
# +----------+-----------+-------------+---------------+---------------+---------------+
# |  119736  |     FL    | CLAY COUNTY |    498960.0   |    498960.0   |    498960.0   |
# |  448094  |     FL    | CLAY COUNTY |   1322376.3   |   1322376.3   |   1322376.3   |
# |  206893  |     FL    | CLAY COUNTY |    190724.4   |    190724.4   |    190724.4   |
# ...

# %%
sf.tail()
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
#
# Rows: 10
#
# Data:
# +----------+-----------+-----------------+---------------+---------------+
# | policyID | statecode |      county     | eq_site_limit | hu_site_limit |
# +----------+-----------+-----------------+---------------+---------------+
# |  827844  |     FL    | PINELLAS COUNTY |      0.0      |    38112.3    |
# |  876385  |     FL    | PINELLAS COUNTY |      0.0      |    18312.3    |
# |  167630  |     FL    | PINELLAS COUNTY |      0.0      |     4522.5    |
# |  241496  |     FL    | PINELLAS COUNTY |      0.0      |     1350.0    |
# ...

# %%
sf.head()
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
#
# Rows: 10
#
# Data:
# +----------+-----------+-------------+---------------+---------------+---------------+
# | policyID | statecode |    county   | eq_site_limit | hu_site_limit | fl_site_limit |
# +----------+-----------+-------------+---------------+---------------+---------------+
# |  119736  |     FL    | CLAY COUNTY |    498960.0   |    498960.0   |    498960.0   |
# |  448094  |     FL    | CLAY COUNTY |   1322376.3   |   1322376.3   |   1322376.3   |
# |  206893  |     FL    | CLAY COUNTY |    190724.4   |    190724.4   |    190724.4   |
# ...

# %%
sf
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
#
# Rows: 36634
#
# Data:
# +----------+-----------+-------------+---------------+---------------+---------------+
# | policyID | statecode |    county   | eq_site_limit | hu_site_limit | fl_site_limit |
# +----------+-----------+-------------+---------------+---------------+---------------+
# |  119736  |     FL    | CLAY COUNTY |    498960.0   |    498960.0   |    498960.0   |
# |  448094  |     FL    | CLAY COUNTY |   1322376.3   |   1322376.3   |   1322376.3   |
# |  206893  |     FL    | CLAY COUNTY |    190724.4   |    190724.4   |    190724.4   |
# ...

# %%
sf.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:51015/index.html
# Opening Canvas in default web browser.
